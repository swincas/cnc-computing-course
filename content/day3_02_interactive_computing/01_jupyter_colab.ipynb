# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/swincas/cnc-computing-course/tree/SteinwenderBradley/content/day3_02_interactive_computing/01_jupyter_colab.ipynb)
#
# Author: Lukas Steinwender

# %%
#installs (uncomment if you run in colab)
# !pip3 install pandas

# %%
#%%imports
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data=np.random.randn(100,5))
df
# Out:
#            0         1         2         3         4
# 0  -0.691651  2.212825 -0.534689  1.133217  0.826988
# 1  -0.584352 -0.004519 -1.742982 -1.004608  0.687383
# 2  -0.365446 -0.070848  0.925394  1.818679  0.236168
# 3  -0.124830 -0.733563 -0.918895 -0.771903  0.876063
# 4   0.496242  1.829241  0.088823 -1.268797 -0.050603
# ..       ...       ...       ...       ...       ...
# 95 -0.047733  1.062744 -0.324374 -2.360889  0.161600
# 96 -0.718741  0.144342  1.137907 -0.588515  0.729222
# 97 -0.038690  0.568988  2.160830 -1.082012  0.220492
# 98  1.465690  1.752437  0.431618 -0.533112 -0.266592
# 99 -0.369781 -0.197046  0.029844 -1.040565 -0.141084
#
# [100 rows x 5 columns]
